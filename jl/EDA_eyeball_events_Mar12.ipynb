# %%
## Read table, combine table, parse the time string, save to pkl
## Visualize the excursion event
import pandas as pd
import matplotlib.pylab as plt
from datetime import datetime
import matplotlib.dates as mdates
import numpy as np
from scipy.fftpack import fft, ifft
from scipy import signal
import numpy as np
from src.utils import *
pd.set_option('display.max_columns', 51)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 20}
plt.rc('font', **font)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
file_df = pd.read_pickle("data/combined.pkl")

# %%
## Set the subsea shutdown tempature from ~ 40 to 0 or null to avoid confusion in the analysis
downhole_temperatures = ["05-TT-34101-04_H1_Manifold_Temperature (DegF)",
                        "05-TT-34101-01_H1_Manifold_Temperature (DegF)",
                        "05-TT-29101-02_C1_Manifold_Temperature (DegF)",
                        "05-TT-29101-03_C1_Manifold_Temperature (DegF)",
                        "05-TT-28201-01_B2_Manifold_Temperature (DegF)",
                        "05-TT-28201-03_B2_Manifold_Temperature (DegF)",
                        "05-TT-33101-03_G1_Manifold_Temperature (DegF)",
                        "05-TT-33101-02_G1_Manifold_Temperature (DegF)"]

file_df = downhole_40_removal(file_df, downhole_temperatures)

# %%
## Mar 12, 2017 (7am Reported Upset)
start_time = datetime(2017, 3, 11, 15, 0)
end_time = datetime(2017, 3, 12, 20,0)
subplot_features(file_df, start_time, end_time, separator_2nd_features_3, 
                 separator_2nd_features_2, separator_2nd_features_1, 
                 lp_filter=True, normalized=False)
# Out:
# /home/computer/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family ['normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
## separator_2nd_features
## separator_1st_1_features
## separator_1st_2_features 
plot_features(file_df, start_time, end_time, separator_2nd_features, lp_filter=True, normalized=True)
plt.title("separator_2nd_features")
plt.show()
plot_features(file_df, start_time, end_time, separator_1st_1_features, lp_filter=True, normalized=True)
plt.title("separator_1st_1_features")
plt.show()
plot_features(file_df, start_time, end_time, separator_1st_2_features, lp_filter=True, normalized=True)
plt.title("separator_1st_2_features")
plt.show()

# %%
plot_features(file_df, start_time, end_time, separator_1st_2_features, lp_filter=True, normalized=True)
plt.title("separator_1st_2_features")
plt.show()
plot_features(file_df, start_time, end_time, heatexchanger_p6_features, lp_filter=True, normalized=True)
plt.title("heatexchanger_p6_features")
plt.show()
plot_features(file_df, start_time, end_time, downhole_B_p_features, lp_filter=True, normalized=True)
plt.title("downhole_B_p6_features")
plt.show()
plot_features(file_df, start_time, end_time, downhole_G_p_features, lp_filter=True, normalized=True)
plt.title("downhole_G_p6_features")
plt.show()

# %%
plot_features(file_df, start_time, end_time, separator_1st_1_features, lp_filter=True, normalized=True)
plt.title("separator_1st_1_features")
plt.show()
plot_features(file_df, start_time, end_time, heatexchanger_p2_features, lp_filter=True, normalized=True)
plt.title("heatexchanger_p2_features")
plt.show()
plot_features(file_df, start_time, end_time, heatexchanger_p1_features, lp_filter=True, normalized=True)
plt.title("heatexchanger_p1_features")
plt.show()
plot_features(file_df, start_time, end_time, downhole_H_p_features, lp_filter=True, normalized=True)
plt.title("downhole_H_p1_features")
plt.show()
plot_features(file_df, start_time, end_time, downhole_C_p_features, lp_filter=True, normalized=True)
plt.title("downhole_C_p1_features")
plt.show()

# %%
## Pressure Trace back
## B to facility 12,500 feet 3810 m, sound speed ~ 1500 m/s. The time lag is 3 s
## Pressure Trace back
start_time = datetime(2017, 3, 11, 20, 20)
end_time = datetime(2017, 3, 12, 4,20)

features = [ "21-LT-10618.PV_Prod_Sep_2nd_Stg_Interface (%)",
            "21-PT-40505.PV_Test_Allocation_Separator (PSIG)",
            "20-PT-20008-01.PV_Flowline_From_Drill_Centers_B&G (PSIG)",
            "20-PT-20008-01.PV_Flowline_From_Drill_Centers_B&G (PSIG)",
            "05-PT-28201-01_B2_Manifold_Pressure (Psi)",
            "05-PT-33101-03_G1_Manifold_Pressure (Psi)"
            ]

plot_features(file_df, start_time, end_time, features, lp_filter=True, normalized=True)
plt.title("Mar 12 First Upset")
plt.show()

# %%
## Pressure Trace back
## B to facility 12,500 feet 3810 m, sound speed ~ 1500 m/s. The time lag is 3 s
## Pressure Trace back
start_time = datetime(2017, 3, 11, 20, 20)
end_time = datetime(2017, 3, 12, 4,20)

features = [ "21-LT-10618.PV_Prod_Sep_2nd_Stg_Interface (%)",
            "21-PT-40505.PV_Test_Allocation_Separator (PSIG)",
            "20-PT-20008-01.PV_Flowline_From_Drill_Centers_B&G (PSIG)",
            "05-PT-28201-01_B2_Manifold_Pressure (Psi)",
            "05-PT-33101-03_G1_Manifold_Pressure (Psi)"
            ]

plot_features(file_df, start_time, end_time, features, lp_filter=True, normalized=True)
plt.title("Mar 12 First Upset")
plt.show()

# %%
## B to facility 12,500 feet 3810 m, sound speed ~ 1500 m/s. The time lag is 3 s
## Pressure Trace back
start_time = datetime(2017, 3, 12, 4, 0)
end_time = datetime(2017, 3, 12, 12,0)

features = [ "21-LT-10618.PV_Prod_Sep_2nd_Stg_Interface (%)",
            "21-PT-40505.PV_Test_Allocation_Separator (PSIG)",
            "20-PT-20008-01.PV_Flowline_From_Drill_Centers_B&G (PSIG)",
            "05-PT-28201-01_B2_Manifold_Pressure (Psi)",
            "05-PT-33101-03_G1_Manifold_Pressure (Psi)"
            ]

plot_features(file_df, start_time, end_time, features, lp_filter=True, normalized=True)
plt.title("Mar 12 Second Upset")
plt.show()

# %%
from scipy.signal import correlate
def timelag(s1, s2):
    '''
    input s1 s2,
    return time lag in no. of sample
    '''
    xcorr = correlate(s1,s1)
    return xcorr

time_range = (file_df["Time"] < end_time) & (file_df["Time"] > start_time)
x = file_df.loc[time_range, ["Time"]].values
s1 = file_df.loc[time_range, ["05-PT-33101-03_G1_Manifold_Pressure (Psi)"]].values
s1 = normalize_for_plot(s1)
s2 = file_df.loc[time_range, ["21-PT-40505.PV_Test_Allocation_Separator (PSIG)"]].values
s2 = normalize_for_plot(s2)
fig = plt.figure(figsize=(15,6))
plt.plot(x, s1, label="s1")
plt.plot(x, s2, label="s2")
plt.legend()
xcorr_test = timelag(s1, s2)
#plt.plot(x, xcorr_test)
