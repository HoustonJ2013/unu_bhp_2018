# %%
## Read table, combine table, parse the time string, save to pkl
## Visualize the excursion event
import pandas as pd
import matplotlib.pylab as plt
from datetime import datetime
import matplotlib.dates as mdates
import numpy as np
from scipy import signal
from scipy.fftpack import fft, ifft
import time
from src.anomaly_detection import *
from src.utils import *
pd.set_option('display.max_columns', 51)
font = {'family' : 'Consolas',
        'weight' : 'bold',
        'size'   : 32}
plt.rc('font', **font)
import os 
dir_path = os.getcwd()
data_dir = os.path.abspath(os.path.join(dir_path, '../data'))
print (data_dir)
combined_pkl = os.path.join(data_dir, "combine.pkl")
combined_pkg_tbl = os.path.join(data_dir, 'combine_table.pkl')
part1_pkl = os.path.join(data_dir, "Part1.pkl")
part2_pkl = os.path.join(data_dir, "Part2.pkl")
# %matplotlib inline
# Out:
# /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data

# %%
file_df = pd.read_pickle("data/combined.pkl")
#file_df.info()

# %%
anomaly_detection = anomaly_detection(sequence_length=100, batch_size=128, epochs=60, dropout=0.6, verbose = 2)
start = time.time()
start_time = datetime(2016, 11, 15,10,0)
end_time = datetime(2016, 11, 16, 10,0)
time_range= (file_df["Time"] < end_time) & (file_df["Time"] > start_time)
column_name = "21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)"
time_series = file_df[time_range][column_name]
anomaly_detection.set_name(column_name)
anomaly_detection.timeseries_fit(time_series, show_figures=True, run_model = True)
# Out:
# /home/computer/anaconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/computer/anaconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# Train on 1853 samples, validate on 926 samples
# Epoch 1/60
# Epoch 00001: val_loss improved from inf to 0.02754, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 9s - loss: 0.0091 - val_loss: 0.0275
# Epoch 2/60
# Epoch 00002: val_loss did not improve
#  - 7s - loss: 0.0036 - val_loss: 0.0335
# Epoch 3/60
# Epoch 00003: val_loss did not improve
#  - 7s - loss: 0.0035 - val_loss: 0.0345
# Epoch 4/60
# Epoch 00004: val_loss did not improve
#  - 7s - loss: 0.0038 - val_loss: 0.0317
# Epoch 5/60
# Epoch 00005: val_loss improved from 0.02754 to 0.02595, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0038 - val_loss: 0.0259
# Epoch 6/60
# Epoch 00006: val_loss improved from 0.02595 to 0.01911, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0036 - val_loss: 0.0191
# Epoch 7/60
# Epoch 00007: val_loss improved from 0.01911 to 0.01434, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0030 - val_loss: 0.0143
# Epoch 8/60
# Epoch 00008: val_loss improved from 0.01434 to 0.01334, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 6s - loss: 0.0027 - val_loss: 0.0133
# Epoch 9/60
# Epoch 00009: val_loss did not improve
#  - 7s - loss: 0.0025 - val_loss: 0.0134
# Epoch 10/60
# Epoch 00010: val_loss did not improve
#  - 7s - loss: 0.0022 - val_loss: 0.0144
# Epoch 11/60
# Epoch 00011: val_loss did not improve
#  - 8s - loss: 0.0021 - val_loss: 0.0161
# Epoch 12/60
# Epoch 00012: val_loss did not improve
#  - 7s - loss: 0.0020 - val_loss: 0.0156
# Epoch 13/60
# Epoch 00013: val_loss did not improve
#  - 7s - loss: 0.0018 - val_loss: 0.0153
# Epoch 14/60
# Epoch 00014: val_loss did not improve
#  - 7s - loss: 0.0019 - val_loss: 0.0135
# Epoch 15/60
# Epoch 00015: val_loss did not improve
#  - 7s - loss: 0.0017 - val_loss: 0.0157
# Epoch 16/60
# Epoch 00016: val_loss did not improve
#  - 7s - loss: 0.0016 - val_loss: 0.0138
# Epoch 17/60
# Epoch 00017: val_loss improved from 0.01334 to 0.01174, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0015 - val_loss: 0.0117
# Epoch 18/60
# Epoch 00018: val_loss improved from 0.01174 to 0.00949, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0015 - val_loss: 0.0095
# Epoch 19/60
# Epoch 00019: val_loss did not improve
#  - 7s - loss: 0.0014 - val_loss: 0.0095
# Epoch 20/60
# Epoch 00020: val_loss improved from 0.00949 to 0.00883, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0012 - val_loss: 0.0088
# Epoch 21/60
# Epoch 00021: val_loss improved from 0.00883 to 0.00792, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0013 - val_loss: 0.0079
# Epoch 22/60
# Epoch 00022: val_loss improved from 0.00792 to 0.00715, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0012 - val_loss: 0.0071
# Epoch 23/60
# Epoch 00023: val_loss improved from 0.00715 to 0.00559, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 8s - loss: 0.0012 - val_loss: 0.0056
# Epoch 24/60
# Epoch 00024: val_loss did not improve
#  - 7s - loss: 0.0011 - val_loss: 0.0088
# Epoch 25/60
# Epoch 00025: val_loss improved from 0.00559 to 0.00492, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0011 - val_loss: 0.0049
# Epoch 26/60
# Epoch 00026: val_loss did not improve
#  - 7s - loss: 0.0011 - val_loss: 0.0128
# Epoch 27/60
# Epoch 00027: val_loss did not improve
#  - 7s - loss: 0.0014 - val_loss: 0.0053
# Epoch 28/60
# Epoch 00028: val_loss did not improve
#  - 7s - loss: 0.0011 - val_loss: 0.0076
# Epoch 29/60
# Epoch 00029: val_loss improved from 0.00492 to 0.00419, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 0.0011 - val_loss: 0.0042
# Epoch 30/60
# Epoch 00030: val_loss did not improve
#  - 7s - loss: 0.0011 - val_loss: 0.0120
# Epoch 31/60
# Epoch 00031: val_loss did not improve
#  - 7s - loss: 0.0013 - val_loss: 0.0058
# Epoch 32/60
# Epoch 00032: val_loss did not improve
#  - 7s - loss: 0.0010 - val_loss: 0.0067
# Epoch 33/60
# Epoch 00033: val_loss did not improve
#  - 7s - loss: 9.4560e-04 - val_loss: 0.0048
# Epoch 34/60
# Epoch 00034: val_loss did not improve
#  - 7s - loss: 8.7209e-04 - val_loss: 0.0045
# Epoch 35/60
# Epoch 00035: val_loss improved from 0.00419 to 0.00408, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 8.6583e-04 - val_loss: 0.0041
# Epoch 36/60
# Epoch 00036: val_loss improved from 0.00408 to 0.00399, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 8.2872e-04 - val_loss: 0.0040
# Epoch 37/60
# Epoch 00037: val_loss improved from 0.00399 to 0.00259, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 8.4333e-04 - val_loss: 0.0026
# Epoch 38/60
# Epoch 00038: val_loss did not improve
#  - 7s - loss: 8.3709e-04 - val_loss: 0.0039
# Epoch 39/60
# Epoch 00039: val_loss did not improve
#  - 7s - loss: 8.3185e-04 - val_loss: 0.0031
# Epoch 40/60
# Epoch 00040: val_loss did not improve
#  - 7s - loss: 7.5462e-04 - val_loss: 0.0060
# Epoch 41/60
# Epoch 00041: val_loss improved from 0.00259 to 0.00205, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 8.8472e-04 - val_loss: 0.0020
# Epoch 42/60
# Epoch 00042: val_loss did not improve
#  - 7s - loss: 9.4959e-04 - val_loss: 0.0129
# Epoch 43/60
# Epoch 00043: val_loss did not improve
#  - 7s - loss: 0.0014 - val_loss: 0.0052
# Epoch 44/60
# Epoch 00044: val_loss did not improve
#  - 7s - loss: 9.4313e-04 - val_loss: 0.0063
# Epoch 45/60
# Epoch 00045: val_loss did not improve
#  - 7s - loss: 8.1662e-04 - val_loss: 0.0034
# Epoch 46/60
# Epoch 00046: val_loss did not improve
#  - 7s - loss: 7.9981e-04 - val_loss: 0.0066
# Epoch 47/60
# Epoch 00047: val_loss did not improve
#  - 7s - loss: 8.4592e-04 - val_loss: 0.0032
# Epoch 48/60
# Epoch 00048: val_loss did not improve
#  - 8s - loss: 8.5625e-04 - val_loss: 0.0031
# Epoch 49/60
# Epoch 00049: val_loss did not improve
#  - 7s - loss: 7.2944e-04 - val_loss: 0.0041
# Epoch 50/60
# Epoch 00050: val_loss did not improve
#  - 7s - loss: 6.8637e-04 - val_loss: 0.0032
# Epoch 51/60
# Epoch 00051: val_loss did not improve
#  - 7s - loss: 7.0302e-04 - val_loss: 0.0025
# Epoch 52/60
# Epoch 00052: val_loss did not improve
#  - 7s - loss: 7.0774e-04 - val_loss: 0.0037
# Epoch 53/60
# Epoch 00053: val_loss improved from 0.00205 to 0.00200, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 7.3192e-04 - val_loss: 0.0020
# Epoch 54/60
# Epoch 00054: val_loss did not improve
#  - 7s - loss: 7.4305e-04 - val_loss: 0.0044
# Epoch 55/60
# Epoch 00055: val_loss did not improve
#  - 7s - loss: 6.9692e-04 - val_loss: 0.0026
# Epoch 56/60
# Epoch 00056: val_loss did not improve
#  - 7s - loss: 7.0297e-04 - val_loss: 0.0032
# Epoch 57/60
# Epoch 00057: val_loss improved from 0.00200 to 0.00180, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 7.4764e-04 - val_loss: 0.0018
# Epoch 58/60
# Epoch 00058: val_loss did not improve
#  - 7s - loss: 6.5936e-04 - val_loss: 0.0056
# Epoch 59/60
# Epoch 00059: val_loss improved from 0.00180 to 0.00174, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/21-LT-10516.PV_Prod_Sep_Oil_Interface_Level (%)_weights.hdf5
#  - 7s - loss: 7.1898e-04 - val_loss: 0.0017
# Epoch 60/60
# Epoch 00060: val_loss did not improve
#  - 7s - loss: 6.8115e-04 - val_loss: 0.0056
# /home/computer/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family ['Consolas'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
anomaly_detection2 = anomaly_detection(sequence_length=100, batch_size=256, epochs=15, dropout=0.6, verbose = 2)
start = time.time()
start_time = datetime(2017, 3, 11,10,0)
end_time = datetime(2017, 3, 12, 20,0)
time_range= (file_df["Time"] < end_time) & (file_df["Time"] > start_time)
column_name = "05-PT-33101-03_G1_Manifold_Pressure (Psi)"
time_series = file_df[time_range][column_name]
anomaly_detection2.set_name(column_name)
anomaly_detection2.timeseries_fit(time_series, show_figures=True, run_model = True)
# Out:
# /home/computer/anaconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/computer/anaconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# Train on 2573 samples, validate on 1286 samples
# Epoch 1/15
# Epoch 00001: val_loss improved from inf to 0.00449, saving model to /media/computer/1TB_disk/10_ML_proj/16_BHP_DigitalTribe/Challenge2FinalData/unu_bhp_2018/data/05-PT-33101-03_G1_Manifold_Pressure (Psi)_weights.hdf5
#  - 7s - loss: 0.0156 - val_loss: 0.0045
# Epoch 2/15

# %%
anomalies = anomaly_detection2.find_anomaly(error_level=0.15)
if anomalies.any():
    print("Found {len(anomalies)} anomalies in {column_name} between {start_time} and {end_time}")
    fig, ax = plt.subplots(figsize=(30,15))
    x = np.asarray(file_df[time_range]['TimeStamp'])
    y = np.asarray(time_series)+
    ax.plot(x, y, color='b')
    for i in anomalies:
        ax.plot(x[i],y[i],'ro')
        ax.xaxis.set_major_formatter(datefmt)
    plt.xlabel('Time Stamp')
    plt.ylabel(column_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-709deddc0acb> in <module>()
# ----> 1 anomalies = anomaly_detection.find_anomaly(self, error_level=0.15)
#       2 # if anomalies.any():
#       3 #     print("Found {len(anomalies)} anomalies in {column_name} between {start_time} and {end_time}")
#       4 #     fig, ax = plt.subplots(figsize=(30,15))
#       5 #     x = np.asarray(file_df[time_range]['TimeStamp'])
#
# NameError: name 'self' is not defined

# %%
start_time = datetime(2017, 3, 2,10,0)
end_time = datetime(2017, 3, 12, 20,0)

features = [ "21-LT-10618.PV_Prod_Sep_2nd_Stg_Interface (%)",
            "21-PT-40505.PV_Test_Allocation_Separator (PSIG)",
            "20-PT-20008-01.PV_Flowline_From_Drill_Centers_B&G (PSIG)",
            "05-PT-28201-01_B2_Manifold_Pressure (Psi)",
            "05-PT-33101-03_G1_Manifold_Pressure (Psi)"
            ]

plot_features(file_df, start_time, end_time, features, lp_filter=True, normalized=True)
plt.title("features")
plt.show()
